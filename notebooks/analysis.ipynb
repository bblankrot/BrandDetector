# %% [markdown]
# ## Comparing baseline to NER for Kaggle data
#
# Here we compare the accuracy of named entity recognition for brands to that of our baseline search, over the adapted [Kaggle data](https://www.kaggle.com/kevinhartman0/advertisement-transcripts-from-various-industries) in `data/additional_data.json`.

# %%
import pandas as pd
import numpy as np
df = pd.read_json('test_data_pred.json')
df_baseline = pd.read_json('baseline_corrects.json')
df_comparison = df[['transcription', 'brand', 'seen_in_training', 'predictions', 'corrects']].join(df_baseline, how='inner')

# %%
def print_accuracy(correct_predictions, string):
    print('{} incorrect, {} correct {} ({:.2f} correct)'.format(
        correct_predictions.shape[0] - correct_predictions.sum(),
        correct_predictions.sum(),
        string,
        correct_predictions.sum() / correct_predictions.shape[0]))
    
print('Model:')
print_accuracy(df_comparison['corrects'], 'overall')
unseen = df_comparison[~df_comparison['seen_in_training']]
print_accuracy(unseen['corrects'], 'in unseen')
print_accuracy(df_comparison[df_comparison['seen_in_training']]['corrects'], 'in seen')
print('---------------------')
print('Baseline:')
print_accuracy(df_comparison['bl_corrects'], 'overall')
print_accuracy(unseen['bl_corrects'], 'in unseen')
print_accuracy(df_comparison[df_comparison['seen_in_training']]['bl_corrects'], 'in seen')
print('---------------------')
# Out:
# Model:
# 100 incorrect, 162 correct overall (0.62 correct)
# 95 incorrect, 52 correct in unseen (0.35 correct)
# 5 incorrect, 110 correct in seen (0.96 correct)
# ---------------------
# Baseline:
# 149 incorrect, 113 correct overall (0.43 correct)
# 147 incorrect, 0 correct in unseen (0.00 correct)
# 2 incorrect, 113 correct in seen (0.98 correct)
# ---------------------

# %% [markdown]
# We can focus specifically on the cases where the brand was already seen but the model returned the wrong brand:

# %%
df_comparison[df_comparison['seen_in_training'] & ~df_comparison['corrects']]
# Out:
#                                           transcription  \
# 94    Children diagnosed with cancer need specialize...
# 680   Could there be a new IRA in your future? Perha...
# 1697  Long distance service you thought couldnt get ...
# 257   Benzel-Busch Motor Car Corporation is one of t...
# 256   For nearly half a century, Benzel-Busch Motor ...
#
#                                        brand  seen_in_training  \
# 94    Memorial Sloan Kettering Cancer Center              True
# 680                         American Express              True
# 1697                                    AT&T              True
# 257       Benzel-Busch Motor Car Corporation              True
# 256       Benzel-Busch Motor Car Corporation              True
#
#                                         predictions  corrects  \
# 94    [Memorial Sloan, Memorial Sloan, Best Cancer]     False
# 680          [Roth IRA, American Express, Roth IRA]     False
# 1697                                             []     False
# 257                [Car Corporation, Mercedes-Benz]     False
# 256                         [Mercedes-Benz Dealers]     False
#
#                                                bl_preds  bl_corrects
# 94             [memorial sloan kettering cancer center]         True
# 680                                          [roth ira]        False
# 1697                                             [at&t]         True
# 257                [benzel busch motor car corporation]         True
# 256   [benzel busch motor car corporation, mercedes ...         True

# %% [markdown]
# Conversely, transcriptions where the model succeeded despite not seeing a particular brand before:

# %%
df_comparison[~df_comparison['seen_in_training'] & df_comparison['corrects']].sample(10)
# Out:
#                                           transcription               brand  \
# 1922  The feast is Europe, and you are the chef. Wor...       World Airways
# 911   My memories of Grandmother always include her ...    Gold Medal Flour
# 844   California almonds are in! When youre talking ...  California Almonds
# 1224  I have a confession to make. I really dont lik...         Green Thumb
# 1546  When youre looking for the hottest basketball ...       Just For Feet
# 452   A curated line up...packed with features like ...   Mitsubishi Motors
# 1675  Its time to get struck...with your 2012-13 Wic...     Wichita Thunder
# 1391  Find your inspiration. Biography Magazine. In ...  Biography Magazine
# 1099  Sick and tired of feeling sick and tired? Use ...             Proleva
# 1555  This week at Publix, enjoy savory Boars Head R...              Publix
#
#       seen_in_training                                        predictions  \
# 1922             False                     [World Airways, World Airways]
# 911              False                       [Grandmas, GOLD MEDAL FLOUR]
# 844              False                               [California Almonds]
# 1224             False                         [Green Thumb, Green Thumb]
# 1546             False                                    [Just For Feet]
# 452              False                                [Mitsubishi Motors]
# 1675             False  [Berry Conference Champion Thunder, Central Ho...
# 1391             False  [Biography Magazine, Ernest Shakletons Antarct...
# 1099             False               [Proleva, Proleva, Proleva, Proleva]
# 1555             False                                    [Publix, Roast]
#
#       corrects  bl_preds  bl_corrects
# 1922      True        []        False
# 911       True  [always]        False
# 844       True        []        False
# 1224      True        []        False
# 1546      True        []        False
# 452       True        []        False
# 1675      True        []        False
# 1391      True        []        False
# 1099      True        []        False
# 1555      True        []        False

# %%
print(df_comparison.loc[1391,'predictions'])
df_comparison.loc[1391,'transcription']
# Out:
# ['Biography Magazine', 'Ernest Shakletons Antarctica', 'Kathleen Turner', 'Biography Magazine']
# 'Find your inspiration. Biography Magazine. In the April issue, Sandra Bullock. Plus, Ernest Shakletons Antarctica. Anne Heche. Kathleen Turner. And much more. For whoever you are, find your inspiration in Biography Magazine. Every life has a story.'
